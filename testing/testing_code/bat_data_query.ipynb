# %% [markdown]
# ### Notebook to download all bat data corresponding to times of FRB's detected by CHIME
# ### By Maxwell A. Fine 2022

# %%
# imports
from swifttools.swift_too import Data
from swifttools.swift_too import ObsQuery
import numpy as np
from astropy.io import fits

from os import listdir
from os.path import isfile, join

# rel path to GAUNO dump spreadsheed 
data_path = '../data'
guano_dump = 'GUANO dump inventory - GUANO triggers.tsv'
guano_path = data_path + '/' + guano_dump
# outdir for guano
outdir = '../data'
skycoords_f_name = 'skycoords' # id ra dec

# redownload / update data? 
clobber=False # true for redonwload

# %%
pwd
# Out:
# '/home/afinemax/khazad-dum/research/SURP2022/working_code'

# %%
# import gauno data dump and produce list of obsids for FRBS that correspond to the GAUNO ids

gauno_dump_data = np.genfromtxt(guano_path,delimiter='\t',) # did not skip header
ids = gauno_dump_data[:,0] # missing leading zeros!

# %%
ras = []
str_ids = []
decs = []

def export_data(ids, ras, decs,):
    '''Exports simulated fractional stokes Q&U values to a text file
    
    Args:
    p_tilda = an array of the average complex polarization for a 1d requency array
    
    File format:
    [freq u q dq du]
    
    Returns = none
    '''
    # grab data


    # write to file
    with open(data_path +'/' + skycoords_f_name +'.dat', 'w') as f:
        # for loop for data
        n = len(ras)
        for i in range(len(ids)): # need to look into writing an array at once a file, and formating
            f.write(str(ids[i]))
            f.write(' ')
            f.write(str(ras[i]))
            f.write(' ')
            f.write(str(decs[i]))
            f.write('\n')
    return

# %%
# query bat data for obsid corresponding to FRBS
for i in range(len(ids-1)): # not sure if this needs to be a forloop
    obsid = str(int(ids[i+1]))
    # since the gauno dump is missing the leading zeros, we add them before fetching,
    # expected format len is 11 digits with leading zeros
    id_len = len(obsid)
    obsid = '0' * (11-id_len) + obsid
    print(obsid)
    data = Data()
    data.obsid = obsid # query data for these observations, note id is a str
    data.bat =    True # fetch data for bat
    data.tdrss = True # x-ray
    
    data.submit() # checks for existence of data 
    data.clobber = clobber
    data.download(outdir=outdir,)
    
    # open fits files 
   # testid = '00013975010'
   # filename = obsid + '/bat/event/' + 'sw' +obsid+'bevshpo_uf.evt.gz' # not all data entries have this format
    mypath = data_path + '/' + obsid +'/auxil' # not all files have /bat/events so using /auxil
    files = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    # need to sort files for a fit file, looking for a '.fits' end to be sure we check a fits file
    for j in files:
        if j[-8:-3] == '.fits':
            myfile = j
            break
    fits_image_filename = data_path +'/' + obsid + '/auxil/' + myfile
    with fits.open(fits_image_filename) as hdul:
        #hdul.info()
        header_dict = hdul[0].header
        ra = header_dict['RA_PNT']
        dec = header_dict['DEC_PNT']
        
    str_ids.append(obsid)
    ras.append(ra)
    decs.append(dec)
    
    export_data(str_ids, ras, decs,)
# check later for UVOT for gifs and sky image 

#newdata = Data(obsid=oq[2].obsid, xrt=True, outdir="~/Downloads") could modify this to one line
# Out:
# 00014807020
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014807020 exists (set clobber=True to override this).
# 00010978060
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00010978060 exists (set clobber=True to override this).
# 00011439003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00011439003 exists (set clobber=True to override this).
# 00014941021
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014941021 exists (set clobber=True to override this).
# 03110925033
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110925033 exists (set clobber=True to override this).
# 03103470003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03103470003 exists (set clobber=True to override this).
# 00014969083
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014969083 exists (set clobber=True to override this).
# 00032619068
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00032619068 exists (set clobber=True to override this).
# 00014969066
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014969066 exists (set clobber=True to override this).
# 00013908036
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013908036 exists (set clobber=True to override this).
# 03103247004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03103247004 exists (set clobber=True to override this).
# 00014935011
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014935011 exists (set clobber=True to override this).
# 00096066254
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096066254 exists (set clobber=True to override this).
# 03110930010
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110930010 exists (set clobber=True to override this).
# 03104083001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03104083001 exists (set clobber=True to override this).
# 00031306077
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031306077 exists (set clobber=True to override this).
# 03104366002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03104366002 exists (set clobber=True to override this).
# 03103123002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03103123002 exists (set clobber=True to override this).
# 00095945039
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095945039 exists (set clobber=True to override this).
# 00095940010
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095940010 exists (set clobber=True to override this).
# 03103060005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03103060005 exists (set clobber=True to override this).
# 00095942014
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095942014 exists (set clobber=True to override this).
# 00056800024
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00056800024 exists (set clobber=True to override this).
# 00014857015
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014857015 exists (set clobber=True to override this).
# 03102905003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03102905003 exists (set clobber=True to override this).
# 00014941003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014941003 exists (set clobber=True to override this).
# 03104167004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03104167004 exists (set clobber=True to override this).
# 03103908001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03103908001 exists (set clobber=True to override this).
# 00095806001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095806001 exists (set clobber=True to override this).
# 00083653001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00083653001 exists (set clobber=True to override this).
# 03104038001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03104038001 exists (set clobber=True to override this).
# 03104038001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03104038001 exists (set clobber=True to override this).
# 03108750001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03108750001 exists (set clobber=True to override this).
# 00031306075
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031306075 exists (set clobber=True to override this).
# 03103240001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03103240001 exists (set clobber=True to override this).
# 00076643009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00076643009 exists (set clobber=True to override this).
# 00014920013
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014920013 exists (set clobber=True to override this).
# 00013509075
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013509075 exists (set clobber=True to override this).
# 00021473001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00021473001 exists (set clobber=True to override this).
# 03104548001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03104548001 exists (set clobber=True to override this).
# 00031306074
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031306074 exists (set clobber=True to override this).
# 00083759001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00083759001 exists (set clobber=True to override this).
# 00013975010
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013975010 exists (set clobber=True to override this).
# 00049890004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00049890004 exists (set clobber=True to override this).
# 00034599009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00034599009 exists (set clobber=True to override this).
# 00014892002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014892002 exists (set clobber=True to override this).
# 00014919001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014919001 exists (set clobber=True to override this).
# 03111051009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03111051009 exists (set clobber=True to override this).
# 00035344123
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00035344123 exists (set clobber=True to override this).
# 00014217026
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014217026 exists (set clobber=True to override this).
# 00041514019
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00041514019 exists (set clobber=True to override this).
# 00048750211
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00048750211 exists (set clobber=True to override this).
# 00034758121
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00034758121 exists (set clobber=True to override this).
# 00059158042
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00059158042 exists (set clobber=True to override this).
# 03111055028
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03111055028 exists (set clobber=True to override this).
# 00013840026
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013840026 exists (set clobber=True to override this).
# 00035344122
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00035344122 exists (set clobber=True to override this).
# 00014889002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014889002 exists (set clobber=True to override this).
# 03110931021
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110931021 exists (set clobber=True to override this).
# 03110973032
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110973032 exists (set clobber=True to override this).
# 00014911002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014911002 exists (set clobber=True to override this).
# 00014911002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014911002 exists (set clobber=True to override this).
# 00076159003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00076159003 exists (set clobber=True to override this).
# 00031888014
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031888014 exists (set clobber=True to override this).
# 03110973029
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110973029 exists (set clobber=True to override this).
# 00076408006
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00076408006 exists (set clobber=True to override this).
# 03110931017
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110931017 exists (set clobber=True to override this).
# 03110973028
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110973028 exists (set clobber=True to override this).
# 03110973028
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110973028 exists (set clobber=True to override this).
# 03110973028
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110973028 exists (set clobber=True to override this).
# 00013674008
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013674008 exists (set clobber=True to override this).
# 00075534010
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00075534010 exists (set clobber=True to override this).
# 03104512005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03104512005 exists (set clobber=True to override this).
# 00013509070
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013509070 exists (set clobber=True to override this).
# 00014352041
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014352041 exists (set clobber=True to override this).
# 00089021004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00089021004 exists (set clobber=True to override this).
# 00095931042
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095931042 exists (set clobber=True to override this).
# 03110975004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110975004 exists (set clobber=True to override this).
# 00048769206
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00048769206 exists (set clobber=True to override this).
# 00012178117
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00012178117 exists (set clobber=True to override this).
# 00031791131
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031791131 exists (set clobber=True to override this).
# 03100438008
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03100438008 exists (set clobber=True to override this).
# 03103364008
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03103364008 exists (set clobber=True to override this).
# 00014851005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014851005 exists (set clobber=True to override this).
# 03104388001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03104388001 exists (set clobber=True to override this).
# 00095945030
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095945030 exists (set clobber=True to override this).
# 00049763013
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00049763013 exists (set clobber=True to override this).
# 00096066177
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096066177 exists (set clobber=True to override this).
# 00014774042
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014774042 exists (set clobber=True to override this).
# 00049446001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00049446001 exists (set clobber=True to override this).
# 03110931010
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110931010 exists (set clobber=True to override this).
# 00014436006
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014436006 exists (set clobber=True to override this).
# 00059149032
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00059149032 exists (set clobber=True to override this).
# 00048709206
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00048709206 exists (set clobber=True to override this).
# 01073893002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/01073893002 exists (set clobber=True to override this).
# 00014821001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014821001 exists (set clobber=True to override this).
# 01071993016
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/01071993016 exists (set clobber=True to override this).
# 01073893000
# ERROR: No data found for 01073893000
# 00036981009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00036981009 exists (set clobber=True to override this).
# 00035462098
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00035462098 exists (set clobber=True to override this).
# 00014808010
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014808010 exists (set clobber=True to override this).
# 01071993011
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/01071993011 exists (set clobber=True to override this).
# 00031791126
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031791126 exists (set clobber=True to override this).
# 01072990004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/01072990004 exists (set clobber=True to override this).
# 00030366225
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00030366225 exists (set clobber=True to override this).
# 00014458015
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014458015 exists (set clobber=True to override this).
# 00031335070
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031335070 exists (set clobber=True to override this).
# 03103149001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03103149001 exists (set clobber=True to override this).
# 00049442007
# Downloading files:   0%|          | 0/36 [00:00<?, ?files/s]
# 00030366202
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00030366202 exists (set clobber=True to override this).
# 00049929030
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00049929030 exists (set clobber=True to override this).
# 01071488008
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/01071488008 exists (set clobber=True to override this).
# 03106403003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03106403003 exists (set clobber=True to override this).
# 00014422005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014422005 exists (set clobber=True to override this).
# 00012841014
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00012841014 exists (set clobber=True to override this).
# 00048785190
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00048785190 exists (set clobber=True to override this).
# 00049670005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00049670005 exists (set clobber=True to override this).
# 00096134132
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096134132 exists (set clobber=True to override this).
# 00032459017
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00032459017 exists (set clobber=True to override this).
# 00046687002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00046687002 exists (set clobber=True to override this).
# 00014769019
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014769019 exists (set clobber=True to override this).
# 00014769019
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014769019 exists (set clobber=True to override this).
# 00014386012
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014386012 exists (set clobber=True to override this).
# 03106203002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03106203002 exists (set clobber=True to override this).
# 03100260002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03100260002 exists (set clobber=True to override this).
# 03109017001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03109017001 exists (set clobber=True to override this).
# 00014769013
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014769013 exists (set clobber=True to override this).
# 00087948002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00087948002 exists (set clobber=True to override this).
# 00036688039
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00036688039 exists (set clobber=True to override this).
# 00087803001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00087803001 exists (set clobber=True to override this).
# 03102677011
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03102677011 exists (set clobber=True to override this).
# 00095671072
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095671072 exists (set clobber=True to override this).
# 00014769010
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014769010 exists (set clobber=True to override this).
# 00036688038
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00036688038 exists (set clobber=True to override this).
# 01069788008
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/01069788008 exists (set clobber=True to override this).
# 00096356012
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096356012 exists (set clobber=True to override this).
# 00013383053
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013383053 exists (set clobber=True to override this).
# 00035101048
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00035101048 exists (set clobber=True to override this).
# 01070298000
# ERROR: No data found for 01070298000
# 00048784191
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00048784191 exists (set clobber=True to override this).
# 00089342002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00089342002 exists (set clobber=True to override this).
# 03109644007
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03109644007 exists (set clobber=True to override this).
# 00014771001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014771001 exists (set clobber=True to override this).
# 03102376004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03102376004 exists (set clobber=True to override this).
# 00086485008
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00086485008 exists (set clobber=True to override this).
# 00014460007
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014460007 exists (set clobber=True to override this).
# 00014460006
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014460006 exists (set clobber=True to override this).
# 00088569001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00088569001 exists (set clobber=True to override this).
# 00087774020
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00087774020 exists (set clobber=True to override this).
# 00014460005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014460005 exists (set clobber=True to override this).
# 00014769004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014769004 exists (set clobber=True to override this).
# 01069551001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/01069551001 exists (set clobber=True to override this).
# 00014375031
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014375031 exists (set clobber=True to override this).
# 01064221005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/01064221005 exists (set clobber=True to override this).
# 03107479004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03107479004 exists (set clobber=True to override this).
# 00095931031
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095931031 exists (set clobber=True to override this).
# 00014664005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014664005 exists (set clobber=True to override this).
# 00014460002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014460002 exists (set clobber=True to override this).
# 00014375029
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014375029 exists (set clobber=True to override this).
# 00031249099
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031249099 exists (set clobber=True to override this).
# 00014459005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014459005 exists (set clobber=True to override this).
# 00013796012
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013796012 exists (set clobber=True to override this).
# 00013977012
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013977012 exists (set clobber=True to override this).
# 00096073006
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096073006 exists (set clobber=True to override this).
# 00096368009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096368009 exists (set clobber=True to override this).
# 00014448001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014448001 exists (set clobber=True to override this).
# 00051951026
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00051951026 exists (set clobber=True to override this).
# 00076587007
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00076587007 exists (set clobber=True to override this).
# 03102484003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03102484003 exists (set clobber=True to override this).
# 00013499096
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013499096 exists (set clobber=True to override this).
# 00095929025
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095929025 exists (set clobber=True to override this).
# 00096445004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096445004 exists (set clobber=True to override this).
# 00049626003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00049626003 exists (set clobber=True to override this).
# 00013486044
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013486044 exists (set clobber=True to override this).
# 00014408012
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014408012 exists (set clobber=True to override this).
# 00014424001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014424001 exists (set clobber=True to override this).
# 00014163021
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014163021 exists (set clobber=True to override this).
# 00013544132
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013544132 exists (set clobber=True to override this).
# 00013509057
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013509057 exists (set clobber=True to override this).
# 00049929017
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00049929017 exists (set clobber=True to override this).
# 00013201174
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013201174 exists (set clobber=True to override this).
# 00013201174
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013201174 exists (set clobber=True to override this).
# 00013201174
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013201174 exists (set clobber=True to override this).
# 03111078008
# Downloading files:   0%|          | 0/34 [00:00<?, ?files/s]
# 01056757010
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/01056757010 exists (set clobber=True to override this).
# 00033349108
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00033349108 exists (set clobber=True to override this).
# 00013201172
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013201172 exists (set clobber=True to override this).
# 00014399001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014399001 exists (set clobber=True to override this).
# 00013995008
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013995008 exists (set clobber=True to override this).
# 00096099001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096099001 exists (set clobber=True to override this).
# 00096134067
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096134067 exists (set clobber=True to override this).
# 03111031001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03111031001 exists (set clobber=True to override this).
# 00096077003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096077003 exists (set clobber=True to override this).
# 00038169011
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00038169011 exists (set clobber=True to override this).
# 00049442006
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00049442006 exists (set clobber=True to override this).
# 03110919031
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110919031 exists (set clobber=True to override this).
# 00039601007
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00039601007 exists (set clobber=True to override this).
# 00096097001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096097001 exists (set clobber=True to override this).
# 00095816023
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095816023 exists (set clobber=True to override this).
# 00096066076
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096066076 exists (set clobber=True to override this).
# 01054681008
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/01054681008 exists (set clobber=True to override this).
# 00034153052
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00034153052 exists (set clobber=True to override this).
# 03110919028
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110919028 exists (set clobber=True to override this).
# 00013800011
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013800011 exists (set clobber=True to override this).
# 00037591051
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00037591051 exists (set clobber=True to override this).
# 00095928018
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095928018 exists (set clobber=True to override this).
# 00096025047
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096025047 exists (set clobber=True to override this).
# 00096133003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096133003 exists (set clobber=True to override this).
# 00075773003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00075773003 exists (set clobber=True to override this).
# 00096115001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096115001 exists (set clobber=True to override this).
# 00096025024
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096025024 exists (set clobber=True to override this).
# 00014331010
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014331010 exists (set clobber=True to override this).
# 00014328004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014328004 exists (set clobber=True to override this).
# 00095730044
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095730044 exists (set clobber=True to override this).
# 03110918010
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110918010 exists (set clobber=True to override this).
# 00035021126
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00035021126 exists (set clobber=True to override this).
# 00046367009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00046367009 exists (set clobber=True to override this).
# 00075976009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00075976009 exists (set clobber=True to override this).
# 00075976009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00075976009 exists (set clobber=True to override this).
# 00013495042
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013495042 exists (set clobber=True to override this).
# 00095929016
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095929016 exists (set clobber=True to override this).
# 00014352002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014352002 exists (set clobber=True to override this).
# 00075097034
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00075097034 exists (set clobber=True to override this).
# 00010905119
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00010905119 exists (set clobber=True to override this).
# 00095931014
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095931014 exists (set clobber=True to override this).
# 00037591041
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00037591041 exists (set clobber=True to override this).
# 00096134044
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096134044 exists (set clobber=True to override this).
# 00036688009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00036688009 exists (set clobber=True to override this).
# 00031385006
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031385006 exists (set clobber=True to override this).
# 03110963002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110963002 exists (set clobber=True to override this).
# 03110838031
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110838031 exists (set clobber=True to override this).
# 00014331002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014331002 exists (set clobber=True to override this).
# 03111061002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03111061002 exists (set clobber=True to override this).
# 00096345004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096345004 exists (set clobber=True to override this).
# 00014326001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014326001 exists (set clobber=True to override this).
# 01048372000
# ERROR: No data found for 01048372000
# 00014318006
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014318006 exists (set clobber=True to override this).
# 00014162019
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014162019 exists (set clobber=True to override this).
# 03111047004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03111047004 exists (set clobber=True to override this).
# 00013995002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013995002 exists (set clobber=True to override this).
# 03103832001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03103832001 exists (set clobber=True to override this).
# 00014314003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014314003 exists (set clobber=True to override this).
# 03110935005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110935005 exists (set clobber=True to override this).
# 00013499095
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013499095 exists (set clobber=True to override this).
# 00013499095
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013499095 exists (set clobber=True to override this).
# 00095817005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095817005 exists (set clobber=True to override this).
# 03110965013
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110965013 exists (set clobber=True to override this).
# 00014260004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014260004 exists (set clobber=True to override this).
# 00086637005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00086637005 exists (set clobber=True to override this).
# 03110965011
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110965011 exists (set clobber=True to override this).
# 00095731005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095731005 exists (set clobber=True to override this).
# 00095829001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095829001 exists (set clobber=True to override this).
# 00096370003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096370003 exists (set clobber=True to override this).
# 00031918112
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031918112 exists (set clobber=True to override this).
# 00095943251
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095943251 exists (set clobber=True to override this).
# 00010374163
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00010374163 exists (set clobber=True to override this).
# 00030375211
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00030375211 exists (set clobber=True to override this).
# 03110944009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110944009 exists (set clobber=True to override this).
# 00095730039
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095730039 exists (set clobber=True to override this).
# 00037760027
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00037760027 exists (set clobber=True to override this).
# 00037760027
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00037760027 exists (set clobber=True to override this).
# 00034748064
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00034748064 exists (set clobber=True to override this).
# 03101782006
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03101782006 exists (set clobber=True to override this).
# 03102753008
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03102753008 exists (set clobber=True to override this).
# 00095943241
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095943241 exists (set clobber=True to override this).
# 00014265005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014265005 exists (set clobber=True to override this).
# 03102753007
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03102753007 exists (set clobber=True to override this).
# 00014197009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014197009 exists (set clobber=True to override this).
# 00074956027
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00074956027 exists (set clobber=True to override this).
# 00095731002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095731002 exists (set clobber=True to override this).
# 00075070019
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00075070019 exists (set clobber=True to override this).
# 00074927034
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00074927034 exists (set clobber=True to override this).
# 00095844003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095844003 exists (set clobber=True to override this).
# 03104103001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03104103001 exists (set clobber=True to override this).
# 00014293001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014293001 exists (set clobber=True to override this).
# 00089149002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00089149002 exists (set clobber=True to override this).
# 00014225011
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014225011 exists (set clobber=True to override this).
# 00096134021
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096134021 exists (set clobber=True to override this).
# 00013939009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013939009 exists (set clobber=True to override this).
# 00013939009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013939009 exists (set clobber=True to override this).
# 00095828002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095828002 exists (set clobber=True to override this).
# 00013289115
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013289115 exists (set clobber=True to override this).
# 00081204002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00081204002 exists (set clobber=True to override this).
# 00032249065
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00032249065 exists (set clobber=True to override this).
# 00032249065
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00032249065 exists (set clobber=True to override this).
# 03110981013
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110981013 exists (set clobber=True to override this).
# 03110941002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110941002 exists (set clobber=True to override this).
# 00096075002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096075002 exists (set clobber=True to override this).
# 00096075002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096075002 exists (set clobber=True to override this).
# 00096380002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096380002 exists (set clobber=True to override this).
# 00070220004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00070220004 exists (set clobber=True to override this).
# 00014094003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014094003 exists (set clobber=True to override this).
# 00095943172
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095943172 exists (set clobber=True to override this).
# 03110960002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110960002 exists (set clobber=True to override this).
# 00096109001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00096109001 exists (set clobber=True to override this).
# 03106091001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03106091001 exists (set clobber=True to override this).
# 00014247004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014247004 exists (set clobber=True to override this).
# 00014247004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014247004 exists (set clobber=True to override this).
# 00014247004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014247004 exists (set clobber=True to override this).
# 00014245003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014245003 exists (set clobber=True to override this).
# 03108619002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03108619002 exists (set clobber=True to override this).
# 00074995036
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00074995036 exists (set clobber=True to override this).
# 03102249005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03102249005 exists (set clobber=True to override this).
# 00095944021
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095944021 exists (set clobber=True to override this).
# 00049754028
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00049754028 exists (set clobber=True to override this).
# 00095945001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095945001 exists (set clobber=True to override this).
# 00010374156
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00010374156 exists (set clobber=True to override this).
# 00035905140
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00035905140 exists (set clobber=True to override this).
# 00014217005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014217005 exists (set clobber=True to override this).
# 00014223005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014223005 exists (set clobber=True to override this).
# 00014223005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014223005 exists (set clobber=True to override this).
# 00014223005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014223005 exists (set clobber=True to override this).
# 03110936010
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110936010 exists (set clobber=True to override this).
# 00095948003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095948003 exists (set clobber=True to override this).
# 03101235003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03101235003 exists (set clobber=True to override this).
# 03101235003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03101235003 exists (set clobber=True to override this).
# 03101235003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03101235003 exists (set clobber=True to override this).
# 03101235003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03101235003 exists (set clobber=True to override this).
# 03101128003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03101128003 exists (set clobber=True to override this).
# 00089160002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00089160002 exists (set clobber=True to override this).
# 03101895005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03101895005 exists (set clobber=True to override this).
# 03101895005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03101895005 exists (set clobber=True to override this).
# 03100654006
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03100654006 exists (set clobber=True to override this).
# 03110161007
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110161007 exists (set clobber=True to override this).
# 03102222003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03102222003 exists (set clobber=True to override this).
# 00086475005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00086475005 exists (set clobber=True to override this).
# 00013908008
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013908008 exists (set clobber=True to override this).
# 03110953006
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110953006 exists (set clobber=True to override this).
# 00013845009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013845009 exists (set clobber=True to override this).
# 03110980003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110980003 exists (set clobber=True to override this).
# 00014162004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014162004 exists (set clobber=True to override this).
# 00038445024
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00038445024 exists (set clobber=True to override this).
# 03101594001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03101594001 exists (set clobber=True to override this).
# 00031702073
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031702073 exists (set clobber=True to override this).
# 00011395061
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00011395061 exists (set clobber=True to override this).
# 00013608067
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013608067 exists (set clobber=True to override this).
# 00013793004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013793004 exists (set clobber=True to override this).
# 00089143002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00089143002 exists (set clobber=True to override this).
# 00036296009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00036296009 exists (set clobber=True to override this).
# 00013802006
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013802006 exists (set clobber=True to override this).
# 00034200052
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00034200052 exists (set clobber=True to override this).
# 03102392005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03102392005 exists (set clobber=True to override this).
# 00014107003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014107003 exists (set clobber=True to override this).
# 00031335062
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031335062 exists (set clobber=True to override this).
# 03110973002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110973002 exists (set clobber=True to override this).
# 00047716021
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00047716021 exists (set clobber=True to override this).
# 00014076011
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014076011 exists (set clobber=True to override this).
# 01036139005
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/01036139005 exists (set clobber=True to override this).
# 00031096020
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00031096020 exists (set clobber=True to override this).
# 03110971007
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110971007 exists (set clobber=True to override this).
# 00089104001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00089104001 exists (set clobber=True to override this).
# 03110989003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110989003 exists (set clobber=True to override this).
# 03103898001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03103898001 exists (set clobber=True to override this).
# 00013499072
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013499072 exists (set clobber=True to override this).
# 03110966004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110966004 exists (set clobber=True to override this).
# 00013504011
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013504011 exists (set clobber=True to override this).
# 03110966003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110966003 exists (set clobber=True to override this).
# 00014012038
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014012038 exists (set clobber=True to override this).
# 00014091001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014091001 exists (set clobber=True to override this).
# 00014091001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014091001 exists (set clobber=True to override this).
# 00045944013
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00045944013 exists (set clobber=True to override this).
# 00038160006
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00038160006 exists (set clobber=True to override this).
# 00047716019
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00047716019 exists (set clobber=True to override this).
# 00013977004
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00013977004 exists (set clobber=True to override this).
# 00059027007
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00059027007 exists (set clobber=True to override this).
# 00035101041
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00035101041 exists (set clobber=True to override this).
# 00014068010
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014068010 exists (set clobber=True to override this).
# 00014104001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014104001 exists (set clobber=True to override this).
# 00048692187
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00048692187 exists (set clobber=True to override this).
# 00089056001
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00089056001 exists (set clobber=True to override this).
# 00014101003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014101003 exists (set clobber=True to override this).
# 00074405029
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00074405029 exists (set clobber=True to override this).
# 03110972002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110972002 exists (set clobber=True to override this).
# 03110966002
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110966002 exists (set clobber=True to override this).
# 00014063008
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014063008 exists (set clobber=True to override this).
# 00036380023
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00036380023 exists (set clobber=True to override this).
# 00054350064
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00054350064 exists (set clobber=True to override this).
# 03110908003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03110908003 exists (set clobber=True to override this).
# 00095943062
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095943062 exists (set clobber=True to override this).
# 00014074012
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00014074012 exists (set clobber=True to override this).
# 00095944003
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095944003 exists (set clobber=True to override this).
# 03109726007
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/03109726007 exists (set clobber=True to override this).
# 00095702009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00095702009 exists (set clobber=True to override this).
# 00036608007
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00036608007 exists (set clobber=True to override this).
# 00033350009
# ERROR: Directory /home/afinemax/khazad-dum/research/SURP2022/data/00033350009 exists (set clobber=True to override this).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_45047/3308825400.py in <module>
#       1 # query bat data for obsid corresponding to FRBS
#       2 for i in range(len(ids-1)): # not sure if this needs to be a forloop
# ----> 3     obsid = str(int(ids[i+1]))
#       4     # since the gauno dump is missing the leading zeros, we add them before fetching,
#       5     # expected format len is 11 digits with leading zeros
#
# ValueError: cannot convert float NaN to integer

# %%
outdir
# Out:
# '../data'

# %%
# since the gauno dump is missing the leading zeros, we add them before fetching,
# expected format len is 11 digits with leading zeros
data = Data()
data.obsid = '00377487000' # query data for these observations, note id is a str
data.bat =    True # fetch data for bat
    
data.submit() # checks for existence of data 
data.clobber = True
data.download(outdir=outdir,)
# Out:
# Downloading files:   0%|          | 0/69 [00:00<?, ?files/s]
# True

# %%
oq = ObsQuery(begin="2020-02-18", length=1)

# %%
oq
# Out:
# Swift_AFST(username='anonymous',begin='2020-02-18 00:00:00',end='2020-02-19 00:00:00',radius='0.19666666666666668')
